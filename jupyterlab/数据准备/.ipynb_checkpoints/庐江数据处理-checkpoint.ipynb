# %%
import numpy as np
import pandas as pd
import os

# %%
file_all_pupil = os.listdir("./Data/pupil/")

# %%
# 时间转换模块，需要将时间转换为字符串
from datetime import datetime
 

def timestamp_to_utc_datetime(timestamp):
 
    """将 13 位整数的毫秒时间戳转化成 utc 时间 (datetime 格式)
    :param timestamp: 13 位整数的时间戳 (1456402864242)
    :return: 返回 datetime 格式 {datetime}2016-02-25 12:21:04.242000
    """

    utc_dt_time = datetime.utcfromtimestamp(timestamp / 1000.0)
    

    return utc_dt_time

# %%
def data_befo_after(path_pupil,path_event):
    file_new_event = pd.read_csv(path_event)
    file_new_pupil = pd.read_csv(path_pupil)
    print(len(file_new_event))
    print(len(file_new_pupil))
    file_new_event['timestamp'] = pd.to_datetime(file_new_event['timestamp'])
    file_new_pupil['timestamp'] = pd.to_datetime(file_new_pupil['timestamp'])
    # 删除实验开始前的数据
    file_new_pupil = file_new_pupil.drop(file_new_pupil[file_new_pupil['timestamp']<file_new_event['timestamp'][0]].index[:-1])
    # 删除实验后的数据
    file_new_pupil = file_new_pupil.drop(file_new_pupil[file_new_pupil['timestamp']>file_new_event['timestamp'][len(file_new_event['timestamp'])-1]].index)
    # 保存到单独的文件夹
    file_new_pupil.to_csv("./Data/processed/"+patient_name+"/"+"sub"+patient_name+".dat",index=False)
    # 保存到组间分析的文件夹
    file_new_pupil.to_csv("分析结果/"+"sub"+patient_name+".dat",index=False)

# %%
def event_fun(patient_name):
    file_event = pd.read_csv("./Data/participants/"+patient_name+".csv")
    file_event = file_event[['timestamp_stake', 'timestamp_stakeDisappear', 'timestamp_spaceship','timestamp_spaceshipResponse', 'timestamp_monster','timestamp_monsterResponse', 'timestamp_reward','transitions','stake']]
    # 删除不符合要求的数据
    for i in ['timestamp_stake', 'timestamp_stakeDisappear', 'timestamp_spaceship','timestamp_spaceshipResponse', 'timestamp_monster','timestamp_monsterResponse', 'timestamp_reward']:
        file_event = file_event.drop(file_event[file_event[i] == 0].index)
    file_event = file_event.reset_index(drop=True)
    file_event["timestamp_end_wang"] = file_event["timestamp_stake"]+9000
    order = ['timestamp_stake', 'timestamp_stakeDisappear', 'timestamp_spaceship',
       'timestamp_spaceshipResponse', 'timestamp_monster',
       'timestamp_monsterResponse', 'timestamp_reward', 'timestamp_end_wang','transitions', 'stake']
    file_event = file_event[order]
    from tqdm import tqdm
    for i in tqdm(file_event.columns[:-2]):
        file_event[i] = file_event[i].apply(timestamp_to_utc_datetime)
    file_event
    file_new_event = pd.DataFrame(columns=["timestamp","message"])
    file_new_event["timestamp"] = file_event.values[:,:-2].flatten()
    temp = []
    for index in tqdm(range(len(file_new_event)//8)):
        temp.append("TRIALID %d"%(index+1))
        temp.append("!V TRIAL_VAR transitions %s"%file_event['transitions'][index])
        temp.append("!V TRIAL_VAR stake %s"%file_event['stake'][index])
        temp.extend(["!E TRIAL_EVENT_VAR response_1","!E TRIAL_EVENT_VAR monster_show","!E TRIAL_EVENT_VAR response_2","!E TRIAL_EVENT_VAR reward","TRIAL_END"])
    file_new_event["message"] = temp
    # 保存到单独的文件夹
    file_new_event.to_csv("./Data/processed/"+patient_name+"/sub"+patient_name+"_events.csv",index=False)
    # 保存到组间分析文件夹
    file_new_event.to_csv("./分析结果/"+"/sub"+patient_name+"_events.csv",index=False)
    # 删除非试验期间数据
    data_befo_after("./Data/processed/"+patient_name+"/"+"sub"+patient_name+".dat","./Data/processed/"+patient_name+"/sub"+patient_name+"_events.csv")

# %%
# 没有对应的游戏数据
temp_no_event_data = []
for i in file_all_pupil:
    import time
    # 读取一个瞳孔文件
    file_pupil = pd.read_csv("./Data/pupil/"+i)
    # 提取患者名称
    patient_name = i.split("-")[0]+"-"+i.split("-")[1]
    # file_event_name = i.split("-")[0]+"-"+i.split("-")[1]+".csv"
    file_new_pupil = pd.DataFrame(columns=["timestamp","pupil_size","pupil_x","pupil_y"])
    
    file_new_pupil["timestamp"] = file_pupil["timestamp_ms"].apply(timestamp_to_utc_datetime)
    file_new_pupil["pupil_size"] = file_pupil["diameter_px"]
    file_new_pupil["pupil_x"] = file_pupil["center_x"]
    file_new_pupil["pupil_y"] = file_pupil["center_y"]
    print("./Data/processed/"+patient_name+"/"+"sub"+patient_name+".dat")
    if os.path.exists("./Data/processed/"+patient_name+"/"):
        print("存在")
    else:
        print("不存在")
        os.mkdir("./Data/processed/"+patient_name+"/")
    # 保存到单独的文件夹
    file_new_pupil.to_csv("./Data/processed/"+patient_name+"/"+"sub"+patient_name+".dat",index=False)
    # 瞳孔数据处理完毕，现在处理事件数据
    
    if os.path.exists("./Data/participants/"+patient_name+".csv"):
        event_fun(patient_name)
        print(patient_name+"对应的文件存在")
    else:
        print(patient_name+"对应的文件不存在")
        temp_no_event_data.append(patient_name)
# Out:
# ./Data/processed/22-001/sub22-001.dat
# 存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.96it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 233/233 [00:00<00:00, 77697.00it/s]
# 1864
# 359164
# 22-001对应的文件存在
# ./Data/processed/22-002/sub22-002.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 313/313 [00:00<00:00, 155381.36it/s]
# 2504
# 931317
# 22-002对应的文件存在
# ./Data/processed/22-004/sub22-004.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.43it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 299/299 [00:00<00:00, 99460.46it/s]
# 2392
# 381811
# 22-004对应的文件存在
# ./Data/processed/22-005/sub22-005.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1340.84it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 294/294 [00:00<00:00, 98863.58it/s]
# 2352
# 384936
# 22-005对应的文件存在
# ./Data/processed/22-006/sub22-006.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1334.70it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 296/296 [00:00<00:00, 150523.03it/s]
# 2368
# 372542
# 22-006对应的文件存在
# ./Data/processed/22-007/sub22-007.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 304/304 [00:00<00:00, 100343.78it/s]
# 2432
# 582867
# 22-007对应的文件存在
# ./Data/processed/22-010/sub22-010.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.28it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 290/290 [00:00<00:00, 96689.04it/s]
# 2320
# 383824
# 22-010对应的文件存在
# ./Data/processed/22-011/sub22-011.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.50it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 260/260 [00:00<00:00, 85935.31it/s]
# 2080
# 447155
# 22-011对应的文件存在
# ./Data/processed/22-012/sub22-012.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1334.23it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 281/281 [00:00<00:00, 93606.50it/s]
# 2248
# 471976
# 22-012对应的文件存在
# ./Data/processed/22-014/sub22-014.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.48it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 254/254 [00:00<00:00, 84719.94it/s]
# 2032
# 359733
# 22-014对应的文件存在
# ./Data/processed/22-017/sub22-017.dat
# 不存在
# 22-017对应的文件不存在
# ./Data/processed/22-018/sub22-018.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.22it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 297/297 [00:00<00:00, 98373.87it/s]
# 2376
# 359915
# 22-018对应的文件存在
# ./Data/processed/22-021/sub22-021.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1330.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 288/288 [00:00<00:00, 144044.78it/s]
# 2304
# 355577
# 22-021对应的文件存在
# ./Data/processed/22-023/sub22-023.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 295/295 [00:00<00:00, 147475.53it/s]
# 2360
# 325936
# 22-023对应的文件存在
# ./Data/processed/22-027/sub22-027.dat
# 不存在
# 22-027对应的文件不存在
# ./Data/processed/22-029/sub22-029.dat
# 不存在
# 22-029对应的文件不存在
# ./Data/processed/22-031/sub22-031.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1332.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 277/277 [00:00<00:00, 138609.19it/s]
# 2216
# 345201
# 22-031对应的文件存在
# ./Data/processed/22-035/sub22-035.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 284/284 [00:00<00:00, 142027.22it/s]
# 2272
# 337362
# 22-035对应的文件存在
# ./Data/processed/22-037/sub22-037.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1602.41it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 285/285 [00:00<00:00, 142970.53it/s]
# 2280
# 335274
# 22-037对应的文件存在
# ./Data/processed/22-038/sub22-038.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1331.16it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 240/240 [00:00<00:00, 121721.04it/s]
# 1920
# 322960
# 22-038对应的文件存在
# ./Data/processed/22-041/sub22-041.dat
# 不存在
# 22-041对应的文件不存在
# ./Data/processed/22-043/sub22-043.dat
# 不存在
# 22-043对应的文件不存在
# ./Data/processed/22-045/sub22-045.dat
# 不存在
# 22-045对应的文件不存在
# ./Data/processed/22-047/sub22-047.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 277/277 [00:00<00:00, 138890.88it/s]
# 2216
# 321380
# 22-047对应的文件存在
# ./Data/processed/22-048/sub22-048.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.91it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 290/290 [00:00<00:00, 96943.35it/s]
# 2320
# 327689
# 22-048对应的文件存在
# ./Data/processed/22-050/sub22-050.dat
# 不存在
# 22-050对应的文件不存在
# ./Data/processed/22-052/sub22-052.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1331.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 312/312 [00:00<00:00, 104992.21it/s]
# 2496
# 331300
# 22-052对应的文件存在
# ./Data/processed/22-053/sub22-053.dat
# 不存在
# 22-053对应的文件不存在
# ./Data/processed/22-055/sub22-055.dat
# 不存在
# 22-055对应的文件不存在
# ./Data/processed/22-058/sub22-058.dat
# 不存在
# 22-058对应的文件不存在
# ./Data/processed/22-061/sub22-061.dat
# 不存在
# 22-061对应的文件不存在
# ./Data/processed/22-062/sub22-062.dat
# 不存在
# 22-062对应的文件不存在
# ./Data/processed/22-065/sub22-065.dat
# 不存在
# 22-065对应的文件不存在
# ./Data/processed/22-065/sub22-065.dat
# 存在
# 22-065对应的文件不存在
# ./Data/processed/22-069/sub22-069.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1610.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 135785.02it/s]
# 2168
# 261896
# 22-069对应的文件存在
# ./Data/processed/22-069/sub22-069.dat
# 存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 271/271 [00:00<00:00, 135477.52it/s]
# 2168
# 79254
# 22-069对应的文件存在
# ./Data/processed/22-072/sub22-072.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1609.87it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 278/278 [00:00<00:00, 93588.29it/s]
# 2224
# 358307
# 22-072对应的文件存在
# ./Data/processed/22-073/sub22-073.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 281/281 [00:00<00:00, 93502.53it/s]
# 2248
# 327618
# 22-073对应的文件存在
# ./Data/processed/22-074/sub22-074.dat
# 不存在
# 22-074对应的文件不存在
# ./Data/processed/22-075/sub22-075.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1609.48it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 302/302 [00:00<00:00, 100673.96it/s]
# 2416
# 108894
# 22-075对应的文件存在
# ./Data/processed/22-075/sub22-075.dat
# 存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 302/302 [00:00<00:00, 100689.97it/s]
# 2416
# 265494
# 22-075对应的文件存在
# ./Data/processed/22-077/sub22-077.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 309/309 [00:00<00:00, 104016.05it/s]
# 2472
# 331628
# 22-077对应的文件存在
# ./Data/processed/22-078/sub22-078.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.12it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 291/291 [00:00<00:00, 97022.45it/s]
# 2328
# 369789
# 22-078对应的文件存在
# ./Data/processed/22-079/sub22-079.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1328.26it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 287/287 [00:00<00:00, 94702.64it/s]
# 2296
# 327297
# 22-079对应的文件存在
# ./Data/processed/22-080/sub22-080.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1601.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 306/306 [00:00<00:00, 152901.72it/s]
# 2448
# 352509
# 22-080对应的文件存在
# ./Data/processed/22-081/sub22-081.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1142.24it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 100350.20it/s]
# 2400
# 349829
# 22-081对应的文件存在
# ./Data/processed/22-082/sub22-082.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1590.86it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 309/309 [00:00<00:00, 103040.22it/s]
# 2472
# 343706
# 22-082对应的文件存在
# ./Data/processed/22-083/sub22-083.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1605.63it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 296/296 [00:00<00:00, 98174.44it/s]
# 2368
# 344420
# 22-083对应的文件存在
# ./Data/processed/22-084/sub22-084.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 297/297 [00:00<00:00, 148528.47it/s]
# 2376
# 346246
# 22-084对应的文件存在
# ./Data/processed/22-085/sub22-085.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 304/304 [00:00<00:00, 102160.76it/s]
# 2432
# 376325
# 22-085对应的文件存在
# ./Data/processed/22-086/sub22-086.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.65it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 303/303 [00:00<00:00, 101047.48it/s]
# 2424
# 338524
# 22-086对应的文件存在
# ./Data/processed/22-088/sub22-088.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1332.79it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 290/290 [00:00<00:00, 96619.92it/s]
# 2320
# 332265
# 22-088对应的文件存在
# ./Data/processed/22-089/sub22-089.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1614.20it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 272/272 [00:00<00:00, 138201.17it/s]
# 2176
# 316499
# 22-089对应的文件存在
# ./Data/processed/22-090/sub22-090.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1334.38it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 305/305 [00:00<00:00, 101803.50it/s]
# 2440
# 341613
# 22-090对应的文件存在
# ./Data/processed/22-091/sub22-091.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 296/296 [00:00<00:00, 99464.35it/s]
# 2368
# 327226
# 22-091对应的文件存在
# ./Data/processed/22-092/sub22-092.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1341.16it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 308/308 [00:00<00:00, 102731.26it/s]
# 2464
# 339438
# 22-092对应的文件存在
# ./Data/processed/22-093/sub22-093.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.89it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 311/311 [00:00<00:00, 102694.74it/s]
# 2488
# 346155
# 22-093对应的文件存在
# ./Data/processed/22-094/sub22-094.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.32it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 290/290 [00:00<00:00, 143285.21it/s]
# 2320
# 341696
# 22-094对应的文件存在
# ./Data/processed/22-095/sub22-095.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1334.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 100937.85it/s]
# 2400
# 324241
# 22-095对应的文件存在
# ./Data/processed/22-096/sub22-096.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1598.44it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 286/286 [00:00<00:00, 94506.50it/s]
# 2288
# 323783
# 22-096对应的文件存在
# ./Data/processed/22-097/sub22-097.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.42it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 298/298 [00:00<00:00, 98378.80it/s]
# 2384
# 339934
# 22-097对应的文件存在
# ./Data/processed/22-098/sub22-098.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1341.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 298/298 [00:00<00:00, 99498.69it/s]
# 2384
# 333676
# 22-098对应的文件存在
# ./Data/processed/22-099/sub22-099.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1339.93it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 308/308 [00:00<00:00, 102731.26it/s]
# 2464
# 455618
# 22-099对应的文件存在
# ./Data/processed/22-100/sub22-100.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 311/311 [00:00<00:00, 155252.15it/s]
# 2488
# 333433
# 22-100对应的文件存在
# ./Data/processed/22-101/sub22-101.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 102235.75it/s]
# 2480
# 335969
# 22-101对应的文件存在
# ./Data/processed/22-102/sub22-102.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1341.69it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 316/316 [00:00<00:00, 105123.74it/s]
# 2528
# 333241
# 22-102对应的文件存在
# ./Data/processed/22-103/sub22-103.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 313/313 [00:00<00:00, 104465.44it/s]
# 2504
# 362857
# 22-103对应的文件存在
# ./Data/processed/22-104/sub22-104.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.27it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 294/294 [00:00<00:00, 97735.23it/s]
# 2352
# 368629
# 22-104对应的文件存在
# ./Data/processed/22-105/sub22-105.dat
# 不存在
# 22-105对应的文件不存在
# ./Data/processed/22-106/sub22-106.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 299/299 [00:00<00:00, 149457.38it/s]
# 2392
# 337044
# 22-106对应的文件存在
# ./Data/processed/22-107/sub22-107.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.32it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 312/312 [00:00<00:00, 103991.01it/s]
# 2496
# 368884
# 22-107对应的文件存在
# ./Data/processed/22-108/sub22-108.dat
# 不存在
# 22-108对应的文件不存在
# ./Data/processed/22-109/sub22-109.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.01it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 155011.24it/s]
# 2480
# 330556
# 22-109对应的文件存在
# ./Data/processed/22-110/sub22-110.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1340.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 280/280 [00:00<00:00, 143115.42it/s]
# 2240
# 328917
# 22-110对应的文件存在
# ./Data/processed/22-111/sub22-111.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 256/256 [00:00<00:00, 126026.04it/s]
# 2048
# 334256
# 22-111对应的文件存在
# ./Data/processed/22-112/sub22-112.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1410.50it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 297/297 [00:00<00:00, 148599.34it/s]
# 2376
# 336776
# 22-112对应的文件存在
# ./Data/processed/22-113/sub22-113.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1559.87it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 292/292 [00:00<00:00, 98570.36it/s]
# 2336
# 332784
# 22-113对应的文件存在
# ./Data/processed/22-114/sub22-114.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 302/302 [00:00<00:00, 100649.96it/s]
# 2416
# 336407
# 22-114对应的文件存在
# ./Data/processed/22-115/sub22-115.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.50it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 286/286 [00:00<00:00, 94454.41it/s]
# 2288
# 340017
# 22-115对应的文件存在
# ./Data/processed/22-116/sub22-116.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1336.30it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 291/291 [00:00<00:00, 145475.86it/s]
# 2328
# 343384
# 22-116对应的文件存在
# ./Data/processed/22-117/sub22-117.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 301/301 [00:00<00:00, 93865.09it/s]
# 2408
# 331873
# 22-117对应的文件存在
# ./Data/processed/22-118/sub22-118.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 154307.14it/s]
# 2512
# 341989
# 22-118对应的文件存在
# ./Data/processed/22-119/sub22-119.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 315/315 [00:00<00:00, 104990.92it/s]
# 2520
# 330068
# 22-119对应的文件存在
# ./Data/processed/22-120/sub22-120.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1327.00it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 306/306 [00:00<00:00, 102007.39it/s]
# 2448
# 363453
# 22-120对应的文件存在
# ./Data/processed/22-121/sub22-121.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1340.68it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 103563.06it/s]
# 2480
# 336386
# 22-121对应的文件存在
# ./Data/processed/22-122/sub22-122.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 313/313 [00:00<00:00, 103160.24it/s]
# 2504
# 338374
# 22-122对应的文件存在
# ./Data/processed/22-123/sub22-123.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1326.16it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 315/315 [00:00<00:00, 103991.01it/s]
# 2520
# 337755
# 22-123对应的文件存在
# ./Data/processed/22-124/sub22-124.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 289/289 [00:00<00:00, 96447.63it/s]
# 2312
# 325137
# 22-124对应的文件存在
# ./Data/processed/22-125/sub22-125.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1597.68it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 148261.01it/s]
# 2400
# 345022
# 22-125对应的文件存在
# ./Data/processed/22-126/sub22-126.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 294/294 [00:00<00:00, 98092.86it/s]
# 2352
# 77205
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1595.47it/s]
#   0%|                                                                                          | 0/294 [00:00<?, ?it/s]
# 22-126对应的文件存在
# ./Data/processed/22-126/sub22-126.dat
# 存在
# 100%|█████████████████████████████████████████████████████████████████████████████| 294/294 [00:00<00:00, 97058.27it/s]
# 2352
# 33664
# 22-126对应的文件存在
# ./Data/processed/22-127/sub22-127.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1603.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 303/303 [00:00<00:00, 151565.19it/s]
# 2424
# 332795
# 22-127对应的文件存在
# ./Data/processed/22-128/sub22-128.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.19it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 305/305 [00:00<00:00, 152438.36it/s]
# 2440
# 326862
# 22-128对应的文件存在
# ./Data/processed/22-129/sub22-129.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 278/278 [00:00<00:00, 138861.08it/s]
# 2224
# 317815
# 22-129对应的文件存在
# ./Data/processed/22-130/sub22-130.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.85it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 103636.41it/s]
# 2512
# 342529
# 22-130对应的文件存在
# ./Data/processed/22-131/sub22-131.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1609.63it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 272/272 [00:00<00:00, 89781.28it/s]
# 2176
# 336175
# 22-131对应的文件存在
# ./Data/processed/22-132/sub22-132.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1333.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 298/298 [00:00<00:00, 99554.17it/s]
# 2384
# 316143
# 22-132对应的文件存在
# ./Data/processed/22-133/sub22-133.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 315/315 [00:00<00:00, 105015.96it/s]
# 2520
# 342487
# 22-133对应的文件存在
# ./Data/processed/22-134/sub22-134.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1340.73it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 313/313 [00:00<00:00, 156548.67it/s]
# 2504
# 333583
# 22-134对应的文件存在
# ./Data/processed/22-135/sub22-135.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1599.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 315/315 [00:00<00:00, 105283.75it/s]
# 2520
# 331372
# 22-135对应的文件存在
# ./Data/processed/22-137/sub22-137.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.73it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 308/308 [00:00<00:00, 102821.21it/s]
# 2464
# 339516
# 22-137对应的文件存在
# ./Data/processed/22-138/sub22-138.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1339.50it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 315/315 [00:00<00:00, 104874.25it/s]
# 2520
# 334465
# 22-138对应的文件存在
# ./Data/processed/22-139/sub22-139.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1602.87it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 310/310 [00:00<00:00, 102850.36it/s]
# 2480
# 330268
# 22-139对应的文件存在
# ./Data/processed/22-140/sub22-140.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1600.19it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 251/251 [00:00<00:00, 123680.72it/s]
# 2008
# 348301
# 22-140对应的文件存在
# ./Data/processed/22-141/sub22-141.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1339.77it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 104657.62it/s]
# 2512
# 331767
# 22-141对应的文件存在
# ./Data/processed/22-142/sub22-142.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1340.78it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 313/313 [00:00<00:00, 104448.81it/s]
# 2504
# 328679
# 22-142对应的文件存在
# ./Data/processed/22-143/sub22-143.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1598.21it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 301/301 [00:00<00:00, 100340.61it/s]
# 2408
# 330512
# 22-143对应的文件存在
# ./Data/processed/22-144/sub22-144.dat
# 不存在
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1332.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 302/302 [00:00<00:00, 100721.99it/s]
# 2416
# 653395
# 22-144对应的文件存在

# %%
print("数据总共"+str(len(file_all_pupil))+"无效率"+str(round(len(temp_no_event_data)/len(file_all_pupil)*100,1))+"%")
# Out:
# 数据总共108无效率15.7%

# %%
temp_no_event_data
# Out:
# []
